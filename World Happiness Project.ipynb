# %%
#necessary imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#importing dataset
happiness=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv")
happiness
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happiness.head(20)  # Top 20 Records
# Out:
#                  Country                           Region  Happiness Rank  \
# 0            Switzerland                   Western Europe               1
# 1                Iceland                   Western Europe               2
# 2                Denmark                   Western Europe               3
# 3                 Norway                   Western Europe               4
# 4                 Canada                    North America               5
# 5                Finland                   Western Europe               6
# 6            Netherlands                   Western Europe               7
# 7                 Sweden                   Western Europe               8
# 8            New Zealand        Australia and New Zealand               9
# 9              Australia        Australia and New Zealand              10
# 10                Israel  Middle East and Northern Africa              11
# 11            Costa Rica      Latin America and Caribbean              12
# ...

# %%
happiness.tail(20) # Bottom 20 Records
# Out:
#                       Country                           Region  \
# 138       Congo (Brazzaville)               Sub-Saharan Africa
# 139                   Comoros               Sub-Saharan Africa
# 140                    Uganda               Sub-Saharan Africa
# 141                   Senegal               Sub-Saharan Africa
# 142                     Gabon               Sub-Saharan Africa
# 143                     Niger               Sub-Saharan Africa
# 144                  Cambodia                Southeastern Asia
# 145                  Tanzania               Sub-Saharan Africa
# 146                Madagascar               Sub-Saharan Africa
# 147  Central African Republic               Sub-Saharan Africa
# 148                      Chad               Sub-Saharan Africa
# 149                    Guinea               Sub-Saharan Africa
# 150               Ivory Coast               Sub-Saharan Africa
# 151              Burkina Faso               Sub-Saharan Africa
# ...

# %%
#checking the shape of tha dataset
happiness.shape
# Out:
# (158, 12)

# %% [markdown]
# This happiness dataset contains 158 Rows and 12 Columns,
# out of 12 Columns 1 is label and remaining 11 is features

# %%
#checking the columns of the dataset
happiness.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ## 1) DATA CLEANING:

# %%
#checking the information(nulls and datatype) in the datset
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#checking the null values in the dataset
happiness.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#total nulls in the dataset
happiness.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# We can see that, There is no nulls in the dataset

# %%
happiness.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# There are 3 different datatypes present in the dataset.
#
# int64 ==> 01 ,
# object ==> 02 ,
# float ==> 09

# %%
#lets visualize it by using heat map
sns.heatmap(happiness.isnull())
# Out:
# <Axes: >

# %% [markdown]
# No Nulls in the dataset

# %%
#checking the value counts of each column
for i in happiness.columns:
    print(happiness[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
#understand data at high level. check the statistics of data set
happiness.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# By looking at Count Row, All Columns having same values(158) which means there is No Nulls in the Dataset.
# By looking at 75% and Max Rows, there is no outliers in the dataset

# %% [markdown]
# ## 2) EDA (Exploratory Data Analysis):

# %%
happiness.shape
# Out:
# (158, 12)

# %%
#separating the numerical and categorical columns
num_columns=[]
cat_columns=[]
for i in happiness:
    if happiness.dtypes[i]=="object":
        cat_columns.append(i)
    else:
        num_columns.append(i)

# %%
#checking the categorical columns
cat_columns
# Out:
# ['Country', 'Region']

# %%
#checking the numerical columns
num_columns
# Out:
# ['Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
len(num_columns)
# Out:
# 10

# %%
#lets see how data is distributed for every column
plt.figure(figsize=(35,20),facecolor='pink')
plotnumber=1
for column in num_columns:
    if plotnumber<11:
        ax=plt.subplot(2,5,plotnumber)
        sns.distplot(happiness[column])
        plt.xlabel(column,fontsize=30)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# we observe that there are outliers at
# standard error,
# family,
# generosity,
# dtstopia residual columns in tha dataset but for the clarify purpose we have to draw box plot for checking outliers

# %%
#visualizing the outliers using Box Plot
plt.figure(figsize=(20,15),facecolor="orange")
plotno=1
for col in num_columns:
    if plotno<=10:
        plt.subplot(2,5,plotno)
        sns.boxplot(happiness[col])
        plt.xlabel(col,fontsize=15)
    plotno+=1
plt.show()

# %% [markdown]
# yes there are outliers are present in dataset at standard error,
# family,
# trust,
# generosity,
# dtstopia residual columns in tha dataset. we have to delete those outliers.

# %%
#1st Quantile
q1=happiness.quantile(0.25)
print("FIRST QUANTILE\n")
print(q1)
print("\n")
 

#3rd Quantile
q3=happiness.quantile(0.75)
print("THIRD QUANTILE\n")
print(q3)
print("\n")

#find the IQR (Inter Quantile Range) to identify outliers
# IQR = Q3 - Q1
iqr=q3-q1
print("INTER QUANTILE RANGE\n")
print(iqr)
# Out:
# FIRST QUANTILE
#
# Happiness Rank                   40.250000
# Happiness Score                   4.526000
# Standard Error                    0.037268
# Economy (GDP per Capita)          0.545808
# Family                            0.856823
# Health (Life Expectancy)          0.439185
# Freedom                           0.328330
# Trust (Government Corruption)     0.061675
# Generosity                        0.150553
# Dystopia Residual                 1.759410
# Name: 0.25, dtype: float64
#
#
# THIRD QUANTILE
#
# Happiness Rank                   118.750000
# Happiness Score                    6.243750
# Standard Error                     0.052300
# Economy (GDP per Capita)           1.158448
# Family                             1.214405
# Health (Life Expectancy)           0.811013
# Freedom                            0.549092
# Trust (Government Corruption)      0.180255
# Generosity                         0.309883
# Dystopia Residual                  2.462415
# ...

# %%
#validating upperside outlier
stderror_high=(q3.Standard Error(1.5*iqr.Standard Error))
print(stderror_high)

#check the indexes which have higher values
ind=np.where(happiness["Standard_Error"]>stderror_high)
print(ind)

#drop the indexes which having high values
happiness=happiness.drop(happiness.index[ind])

#shape of the dataset
happiness.shape

#reset indexes
happiness.reset_index()
# Out:
#   Cell In[103], line 2
#     stderror_high=(q3.Standard Error(1.5*iqr.Standard Error))
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
